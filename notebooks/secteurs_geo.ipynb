# %%
# %pip install geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import geopandas as gpd
import pandas as pd

# %%
import sys
sys.path.append("..")

# %%
from config import SECTEURS_GEO_PATH

secteurs_raw = gpd.read_file(SECTEURS_GEO_PATH)

display(secteurs_raw)
# Out:
#        objectid  cd_sector            tx_sector_descr_nl  \
# 0             1  11001A00-            AARTSELAAR-CENTRUM
# 1             2  11001A01-                  DE LEEUWERIK
# 2             3  11001A020                     BUERSTEDE
# 3             4  11001A030                      YSSELAAR
# 4             5  11001A042                 KLEINE GRIPPE
# ...         ...        ...                           ...
# 20776     20777  93090G191                BOIS DE NISMES
# 20777     20778  93090H000                DOURBES-CENTRE
# 20778     20779  93090H012  DOURBES ROUTE DE MARIEMBOURG
# 20779     20780  93090H063                         LORET
# 20780     20781  93090H091               ROCHE A L'HOMME
#
#                  tx_sector_descr_fr            tx_sector_descr_de  \
# 0                AARTSELAAR-CENTRUM            AARTSELAAR-CENTRUM
# 1                      DE LEEUWERIK                  DE LEEUWERIK
# 2                         BUERSTEDE                     BUERSTEDE
# ...
